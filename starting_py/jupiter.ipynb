# %%
print("HI BRO WELCOME TO THE WORLD OF PYTHON")
# Out:
# HI BRO WELCOME TO THE WORLD OF PYTHON

# %%
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['A', 'B', 'C', 'D'],
    'Values': [10, 20, 15, 25]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Set the style of the visualization
sns.set(style="whitegrid")

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Values', data=df)
plt.title('Category vs Values')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()
