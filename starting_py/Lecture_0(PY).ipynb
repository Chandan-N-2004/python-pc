# %% [markdown]
# # **Lecture 1**
#
# # *Functions*

# %%
name = input ("can i know ur name ? ")
reg_number = input ("what is ur reg number? ")
print( ' hello ' +name   +reg_number+ ' welcome to the event') #name = sir
print(name, end="")
print(reg_number)
# Out:
#  hello chandan sir ur reg number is 2025879, welcome to the event
# chandan sir ur reg number is 2025879,

# %%
print("hello buddy", sep="123", end=" ")
print("lets party")
# Out:
# hello buddy lets party

# %%
name = input("")
print(f"hello,{name}")
# Out:
# hello,roy

# %%
# to remove white space & capatalize every 1st letter&split & split 1 st and 2nd word

name = input("HEY BUDDY WHAT'S UR NAME").strip().title() # remove white space & capitalize every 1st letter
#name = name.strip() # remove white space    
#name = name.title() # capitalize every 1st letter
#name = name.split() # split the string into list of words
#print(name) # print the list of words
first , last = name.split(" ")
print(f"what,{first}")
# Out:
# what,Aaaaa

# %%
# to add an Intger or float numbers

x = float(input("enter x value"))
y = float(input("enter y value"))
#sum = x + y 
print(round(x+y))
#print( x+y) // (x-y) // (x/y)
# Out:
# 9
