# %% [markdown]
# # **LECTURE 3**

# %% [markdown]
# #### loops

# %% [markdown]
# **While** condtion

# %%
i = 5
while i != 0:
    print ("meow")
    i = i - 1    #i -=1
# Out:
# meow
# meow
# meow
# meow
# meow

# %%
i = 0
while i < 4:
    print ("bowww bow")
    i =i + 1
# Out:
# bowww bow
# bowww bow
# bowww bow
# bowww bow

# %% [markdown]
# **for** condtion

# %%
for i in [1,2,3,4,5,7]:
# WE CAN REPALCE I WITH _(UNDERSCORE) IF WE DONT WANT TO SPECIFY THE VARIABLE ( NAMES )
    print ('dump me out')
# Out:
# dump me out
# dump me out
# dump me out
# dump me out
# dump me out
# dump me out

# %%
# another way to write the above code by using range

for i in range (6): # by using range function we are able to generate as many sequence of numbers eg..,1 croe
    print ('help me !!')
# Out:
# help me !!
# help me !!
# help me !!
# help me !!
# help me !!
# help me !!

# %%
# this would be the simple wqy to write the meow in n number of times
print ("MEOW\n" * 5 ,end = "")
# Out:
# MEOW
# MEOW
# MEOW
# MEOW
# MEOW

# %%
# In this below code we are tryinf to read again and again the input value of x until the user enters the positive value (eg.., 1,2,3,) not negative value (eg.., -1,-2,-3)
n = int ( input( 'value of x:'))

if n < 0:
    print ('x is negative')
if n < 0:
    print ("reEnter value of x:")
# Out:
# x is negative
# reEnter value of x:

# %%
# as above we need to print if loop again and again until the user enters the positive value, so instead of this we can use [while True]

while True:
    n = int  ( input ( "vsalue of x="))
    if n > 0:
        break
    
for _ in range (n):
    print ( 'meow...')
# Out:
# meow...
# meow...
# meow...
# meow...
# meow...

# %%
# now we are going to define and write the code usinf def method;

def main():
    number = value_off()
    meow(num)
 
def value_off():
    while True:
        n = int (input("value of x:"))
        if n > 0:
            return n
        
def meow(n):
    for num in range(n):
        print('meow...meow...meow...')         

main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 17
#      14     for num in range(n):
#      15         print('meow...meow...meow...')
# ---> 17 main()
#
# Cell In[59], line 5, in main()
#       3 def main():
#       4     number = value_off()
# ----> 5     meow(num)
#
# NameError: name 'num' is not defined

# %%
STUDENT = ["john","surya","harry"]

print (STUDENT[0])
print (STUDENT[1])
print (STUDENT[2])
# Out:
# john
# surya
# harry

# %%
name = input("enter your name:")

    print("hello", name)
# Out:
#   Cell In[4], line 3
#     print("hello", name)
#     ^
# IndentationError: unexpected indent
